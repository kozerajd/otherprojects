# %%
import numpy as np
from numpy.linalg import lstsq
import matplotlib.pyplot as plt

data = np.array([[752, 1173.208],
                 [844, 1332.491]])

points = [data[0],data[1]]
x_coords, y_coords = zip(*points)
A = np.vstack([x_coords,np.ones(len(x_coords))]).T
m, c = lstsq(A, y_coords)[0]
print("Line Solution is y = {m}x + {c}".format(m=m,c=c))

plt.plot(data[:,0], data[:,1])
plt.title("Regression of Co-60 (HEGe Detector)")
plt.xlabel("Channel Number")
plt.ylabel("Energy (KeV)")
# Out:
# Line Solution is y = 1.7313369565217376x + -128.75739130434616
# C:\Users\kozy8\AppData\Local\Temp\ipykernel_14316\3808237286.py:11: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, c = lstsq(A, y_coords)[0]
# Text(0, 0.5, 'Energy (KeV)')
