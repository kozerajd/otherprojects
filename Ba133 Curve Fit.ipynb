# %%
import numpy as np
from numpy.linalg import lstsq
import matplotlib.pyplot as plt

data = np.array([[50, 80.998],
                 [101, 160.59],
                 [130, 223.22],
                 [179, 276.397],
                 [195, 302.851],
                 [230, 356.005],
                 [248, 383.851]])

points = [data[0],data[1]]
x_coords, y_coords = zip(*points)
A = np.vstack([x_coords,np.ones(len(x_coords))]).T
m, c = lstsq(A, y_coords)[0]
print("Line Solution is y = {m}x + {c}".format(m=m,c=c))

a, b = np.polyfit(data[:,0], data[:,1], 1)
plt.plot(data[:,0], a*data[:,0]+b)

plt.scatter(data[:,0], data[:,1])
plt.title("Ba-133 (HEGe Detector)")
plt.xlabel("Channel Number")
plt.ylabel("Energy (KeV)")
# Out:
# Line Solution is y = 1.5606274509803921x + 2.966627450980385
# C:\Users\kozy8\AppData\Local\Temp\ipykernel_26944\2094787446.py:16: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, c = lstsq(A, y_coords)[0]
# Text(0, 0.5, 'Energy (KeV)')
